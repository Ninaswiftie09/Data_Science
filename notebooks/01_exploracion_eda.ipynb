# %% [markdown]
# # Exploración y análisis de la serie temporal
#
# En este notebook se analiza la temperatura promedio mensual de Guatemala.
#
# Se explora la serie, su tendencia, su estacionalidad y su estacionariedad en media y varianza.

# %%
# %run ../src/03_analisis_serie.py
# Out:
# --- SERIE TEMPORAL ---
# Variable: temperature_2m_c
# Cantidad de meses: 882
# Fecha inicial: 1950-01-01 00:00:00
# Fecha final: 2023-06-01 00:00:00
# Valores nulos: 0
# --- TENDENCIA ---
# Cambio aproximado por año: 0.0158 °C
# Cambio aproximado por década: 0.158 °C
# La serie presenta una tendencia ascendente.
# --- PRUEBA ADF ---
# Estadístico ADF: -4.357
# Valor p: 0.000353
# ADF indica que la serie es estacionaria.
#
# --- PRUEBA KPSS EN MEDIA ---
# Estadístico KPSS: 2.4193
# Valor p: 0.01
# KPSS indica que la media no es estacionaria.
#
# --- PRUEBA KPSS CON TENDENCIA ---
# Estadístico KPSS: 0.044
# Valor p: 0.1
# La serie puede ser estacionaria alrededor de una tendencia.
#
# --- ESTACIONARIEDAD EN VARIANZA ---
# Varianza de la primera mitad: 2.3195
# Varianza de la segunda mitad: 2.2706
# Valor p de Levene: 0.930863
# No se encontraron diferencias significativas entre las varianzas.
#
# Resultados guardados correctamente.
